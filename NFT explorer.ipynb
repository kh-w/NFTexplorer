# %%
pip install git+https://github.com/pcko1/etherscan-python.git
# Out:
# ...
#   Cloning https://github.com/pcko1/etherscan-python.git to c:\users\woodr\appdata\local\temp\pip-req-build-ohh6vj96
#   Resolved https://github.com/pcko1/etherscan-python.git to commit e059d7c91071d8999b8aaf90edb9bf7c488a110d
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/pcko1/etherscan-python.git 'C:\Users\woodr\AppData\Local\Temp\pip-req-build-ohh6vj96'

# %%
from etherscan import Etherscan
eth = Etherscan('9RYTZ8Z6M1KCFDZHHC3GXIRNZRH2SF2VUU') # key in quotation marks

# %%
my_bal = eth.get_eth_balance(address="0x19322ED21EaA143b270E826167532Ab339acEB49")
float(my_bal)/(10**18)
# Out:
# 0.2824316755600643

# %%
random_bal = eth.get_eth_balance(address="0x077D360f11D220E4d5D831430c81C26c9be7C4A4")
float(random_bal)/(10**18)
# Out:
# 37.88918262198909

# %%
pip install opensea-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opensea-api -U
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the OpenseaAPI object from the opensea module
from opensea import OpenseaAPI

# %%
api = OpenseaAPI(apikey="YOUR APIKEY")

# %%
# fetch a single asset
contract_address = "0x1D3aDa5856B14D9dF178EA5Cab137d436dC55F1D"
token_id = "5462"
result = api.asset(asset_contract_address=contract_address, token_id=token_id)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       2 contract_address = "0x1D3aDa5856B14D9dF178EA5Cab137d436dC55F1D"
#       3 token_id = "5462"
# ----> 4 result = api.asset(asset_contract_address=contract_address, token_id=token_id)
#
# File ~\anaconda3\lib\site-packages\opensea\opensea_api.py:252, in OpenseaAPI.asset(self, asset_contract_address, token_id, account_address, export_file_name)
#     250 endpoint = f"asset/{asset_contract_address}/{token_id}"
#     251 query_params = {"account_address": account_address}
# --> 252 return self._make_request(endpoint, query_params, export_file_name)
#
# File ~\anaconda3\lib\site-packages\opensea\opensea_api.py:73, in OpenseaAPI._make_request(self, endpoint, params, export_file_name, return_response)
#      71     raise ValueError(response.text)
#      72 elif response.status_code == 401:
# ...
